# %%
import sys
print(sys.executable)
# Out:
# c:\Users\User\OneDrive\Desktop\study nd stuff\M.Tech\LangGraph Tutorial\.venv\Scripts\python.exe

# %%
# !pip --version
# Out:
# pip 26.1.2 from C:\Users\User\OneDrive\Desktop\study nd stuff\M.Tech\LangGraph Tutorial\.venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

load_dotenv(".env.groq")
# Out:
# True

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\User\OneDrive\Desktop\study nd stuff\M.Tech\LangGraph Tutorial\.venv\Scripts\python.exe

# %%
import subprocess
subprocess.run([sys.executable, "-m", "pip", "show", "langchain-groq"])
# Out:
# CompletedProcess(args=['c:\\Users\\User\\OneDrive\\Desktop\\study nd stuff\\M.Tech\\LangGraph Tutorial\\.venv\\Scripts\\python.exe', '-m', 'pip', 'show', 'langchain-groq'], returncode=1)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\User\OneDrive\Desktop\study nd stuff\M.Tech\LangGraph Tutorial\.venv\Scripts\python.exe

# %%
import subprocess

subprocess.run([sys.executable, "-m", "pip", "install", "langchain-groq"])
# Out:
# CompletedProcess(args=['c:\\Users\\User\\OneDrive\\Desktop\\study nd stuff\\M.Tech\\LangGraph Tutorial\\.venv\\Scripts\\python.exe', '-m', 'pip', 'install', 'langchain-groq'], returncode=0)

# %%
from langchain_groq import ChatGroq
