# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_groq import ChatGroq
from langgraph.checkpoint.memory import InMemorySaver

# %%
from dotenv import load_dotenv

load_dotenv(".env.groq")

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

# %%
class JokeState(TypedDict):
    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state):

    prompt= f'generate a joke on the topic{state["topic"]}'
    response=llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. \n\nThe setup "Why was the pizza in a bad mood?" primes the listener to expect a reason related to the pizza\'s emotional state. The word "crusty" has a double meaning here:\n\n1. **Literal meaning**: In the context of pizza, "crusty" refers to the outer layer of the pizza, which is typically crunchy and golden brown.\n2. **Figurative meaning**: "Crusty" can also describe someone who is irritable, gruff, or ill-tempered, much like a person with a rough exterior.\n\nThe punchline "Because it was feeling a little crusty!" exploits this dual meaning, creating a wordplay that connects the pizza\'s physical characteristic (having a crust) to its emotional state (being in a bad mood). The humor comes from the unexpec
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. \n\nThe setup "Why was the pizza in a bad mood?" primes the listener to expect a reason related to the pizza\'s emotional state. The word "crusty" has a double meaning here:\n\n1. **Literal meaning**: In the context of pizza, "crusty" refers to the outer layer of the pizza, which is typically crunchy and golden brown.\n2. **Figurative meaning**: "Crusty" can also describe someone who is irritable, gruff, or ill-tempered, much like a person with a rough exterior.\n\nThe punchline "Because it was feeling a little crusty!" exploits this dual meaning, creating a wordplay that connects the pizza\'s physical characteristic (having a crust) to its emotional state (being in a bad mood). The humor comes from the unexpe
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a relationship!',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. \n\nThe setup "Why was the pizza in a bad mood?" primes the listener to expect a reason related to the pizza\'s emotional state. The word "crusty" has a double meaning here:\n\n1. **Literal meaning**: In the context of pizza, "crusty" refers to the outer layer of the pizza, which is typically crunchy and golden brown.\n2. **Figurative meaning**: "Crusty" can also describe someone who is irritable, gruff, or ill-tempered, much like a person with a rough exterior.\n\nThe punchline "Because it was feeling a little crusty!" exploits this dual meaning, creating a wordplay that connects the pizza\'s physical characteristic (having a crust) to its emotional state (being in a bad mood). The humor comes from the unexpec
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. \n\nThe setup "Why was the pizza in a bad mood?" primes the listener to expect a reason related to the pizza\'s emotional state. The word "crusty" has a double meaning here:\n\n1. **Literal meaning**: In the context of pizza, "crusty" refers to the outer layer of the pizza, which is typically crunchy and golden brown.\n2. **Figurative meaning**: "Crusty" can also describe someone who is irritable, gruff, or ill-tempered, much like a person with a rough exterior.\n\nThe punchline "Because it was feeling a little crusty!" exploits this dual meaning, creating a wordplay that connects the pizza\'s physical characteristic (having a crust) to its emotional state (being in a bad mood). The humor comes from the unexpe
# ...

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f1748c1-26d4-6f73-8000-62e6fa5a454f"}})
# Out:
# StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f1748c1-26d4-6f73-8000-62e6fa5a454f'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-30T14:00:37.859313+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1748c1-26cd-6a3d-bfff-236e0d2422f4'}}, tasks=(PregelTask(id='0f107a42-f001-fc83-7792-9684d7d0c479', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f1748c1-26d4-6f73-8000-62e6fa5a454f"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. \n\nThe setup "Why was the pizza in a bad mood?" primes the listener to expect a reason related to the pizza\'s emotional state. The word "crusty" has a double meaning here:\n\n1. **Literal meaning**: In the context of pizza, "crusty" refers to the outer layer of the pizza, which is typically crunchy and golden brown.\n2. **Figurative meaning**: "Crusty" can also describe someone who is irritable, gruff, or ill-tempered, much like a person with a rough exterior.\n\nThe punchline "Because it was feeling a little crusty!" exploits this dual meaning, creating a wordplay that connects the pizza\'s physical characteristic (having a crust) to its emotional state (being in a bad mood). The humor comes from the unexpe
# ...

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f1748ed-19fa-63d4-8000-430343995bcc'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1748ed-19fa-63d4-8000-430343995bcc'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-06-30T14:20:17.627438+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='37ce6a5e-a82a-af16-280b-d2f601ab4433', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f1748c1-26d4-6f73-8000-62e6fa5a454f"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. \n\nThe setup "Why was the pizza in a bad mood?" primes the listener to expect a reason related to the pizza\'s emotional state. The word "crusty" has a double meaning here:\n\n1. **Literal meaning**: In the context of pizza, "crusty" refers to the outer layer of the pizza, which is typically crunchy and golden brown.\n2. **Figurative meaning**: "Crusty" can also describe someone who is irritable, gruff, or ill-tempered, much like a person with a "crusty" personality.\n\nThe punchline "Because it was feeling a little crusty!" exploits this dual meaning, creating a wordplay that connects the pizza\'s physical characteristic (its crust) to its emotional state (being in a bad mood). The humor comes from the unexp
# ...
